# %% [markdown]
# # WIlhelm Lange
# ## 02/19/2026
# ### Python - FIles and Data Basics

# %% [markdown]
# - built in magic commands %
# - magics are specific to and provided by the Ipython kernal
# - %% for multiple lines

# %%
# %%writefile file1.txt
# Hi, I am a student in CIS310
# I am using magic commands to create this file
# Out:
# Writing file1.txt

# %%
f = open('file1.txt')

# %%
f.read()
# Out:
# 'Hi, I am a student in CIS310\nI am using magic commands to create this file\n'

# %%
f.read()
# Out:
# ''

# %%
f.seek(0)
# Out:
# 0

# %%
f.read()
# Out:
# 'Hi, I am a student in CIS310\nI am using magic commands to create this file\n'

# %%
f.readline()
# Out:
# ''

# %%
f.seek(0)
# Out:
# 0

# %%
f.readline()
# Out:
# 'Hi, I am a student in CIS310\n'

# %%
f.readline()
# Out:
# 'I am using magic commands to create this file\n'

# %%
f.readline()
# Out:
# ''

# %%
f.seek(0)
# Out:
# 0

# %%
f.seek(1)
# Out:
# 1

# %%
f.readline()
# Out:
# 'i, I am a student in CIS310\n'

# %%
# %%writefile demofile.txt
# Hi, Welcome to Python Files.
# This file is only for testing.
# You can put any text in it.
# Good luck!
# Out:
# Writing demofile.txt

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 5C98-3B99
#
#  Directory of C:\Users\andaconda\Desktop\CIS-310-Repository\2026SP\wk5
#
# 02/19/2026  01:15 PM    <DIR>          .
# 02/19/2026  01:15 PM    <DIR>          ..
# 02/19/2026  01:02 PM    <DIR>          .ipynb_checkpoints
# 02/19/2026  01:15 PM               103 demofile.txt
# 02/19/2026  01:07 PM                77 file1.txt
# 02/19/2026  01:15 PM             5,462 py_files.ipynb
#                3 File(s)          5,642 bytes
#                3 Dir(s)  25,371,144,192 bytes free

# %%
pwd
# Out:
# 'C:\\Users\\andaconda\\Desktop\\CIS-310-Repository\\2026SP\\wk5'

# %%
f_read = open('demofile.txt', 'r')

# %%
f_read.read()
# Out:
# 'Hi, Welcome to Python Files.\nThis file is only for testing.\nYou can put any text in it.\nGood luck!\n'

# %%
f_read.seek(0)
# Out:
# 0

# %%
f_read.readline()
# Out:
# 'Hi, Welcome to Python Files.\n'

# %%
f_read.readline()
# Out:
# 'This file is only for testing.\n'

# %%
f_read.readline()
# Out:
# 'You can put any text in it.\n'

# %%
f_read.readline()
# Out:
# 'Good luck!\n'

# %%
f_read.seek(0)
# Out:
# 0

# %%
f_read.readlines()
# Out:
# ['Hi, Welcome to Python Files.\n',
#  'This file is only for testing.\n',
#  'You can put any text in it.\n',
#  'Good luck!\n']

# %%
f_read.seek(0)
lst = f_read.readlines()

# %%
lst
# Out:
# ['Hi, Welcome to Python Files.\n',
#  'This file is only for testing.\n',
#  'You can put any text in it.\n',
#  'Good luck!\n']

# %%
lst[0]
# Out:
# 'Hi, Welcome to Python Files.\n'

# %%
print(lst[1])
# Out:
# This file is only for testing.

# %%
print(lst[-2:])
# Out:
# ['You can put any text in it.\n', 'Good luck!\n']

# %%
f_read.write('Hello, I am adding a new line!')
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# <ipython-input-32-7f070f403175> in <module>
# ----> 1 f_read.write('Hello, I am adding a new line!')
#
# UnsupportedOperation: not writable

# %%
fw = open('demofile.txt', 'w+')
fw
# Out:
# <_io.TextIOWrapper name='demofile.txt' mode='w+' encoding='cp1252'>

# %%
fw.read()
# Out:
# ''

# %%
fw.write("Hello. I am ading a new line.")
# Out:
# 29

# %%
fw.write("Add another line")
# Out:
# 16

# %%
fw.read()
# Out:
# ''

# %%
fw.seek(0)
# Out:
# 0

# %%
fw.read()
# Out:
# 'Hello. I am ading a new line.Add another line'

# %%
fa = open("demofile.txt", 'a+')
fa
# Out:
# <_io.TextIOWrapper name='demofile.txt' mode='a+' encoding='cp1252'>

# %%
fa.append("Add line 2")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-bbba06533007> in <module>
# ----> 1 fa.append("Add line 2")
#
# AttributeError: '_io.TextIOWrapper' object has no attribute 'append'

# %%
fa.write("add line 2.")
# Out:
# 11

# %%
fa.seek(0)
# Out:
# 0

# %%
fa.read()
# Out:
# 'Hello. I am ading a new line.Add another lineadd line 2.add line 2.'

# %%
fa.write('\n Add line 4')
# Out:
# 12

# %%
fa.seek(0)
# Out:
# 0

# %%
fa.read()
# Out:
# 'Hello. I am ading a new line.Add another lineadd line 2.add line 2.\n Add line 4'

# %%
f.close()
f_read.close()
fw.close()
fa.close()

# %%
#csv and json files
import pandas as pd
