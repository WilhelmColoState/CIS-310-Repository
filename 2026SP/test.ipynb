# %%
I = [1,2,3,4,5,6]
print(I[0:-2])
# Out:
# [1, 2, 3, 4]

# %%
def f(*num):
    print(num)
    
f(1)
f(1,2,3)
f(1,2,3,4,5)
# Out:
# (1,)
# (1, 2, 3)
# (1, 2, 3, 4, 5)

# %%
x = 0
while (x<10):
    x+=3
print(x)
# Out:
# 12

# %%
lists = [[1,2],[3,4,5],[6,7,8,9]]
long_lists = list(filter(lambda n: len(lists[n]) > 2, lists))
long_lists
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-ed9779ae0efa> in <module>
#       1 lists = [[1,2],[3,4,5],[6,7,8,9]]
# ----> 2 long_lists = list(filter(lambda n: len(lists[n]) > 2, lists))
#       3 long_lists
#
# TypeError: 'list' object is not callable

# %%
if 'bar' in ['foo','bar', 'baz']:
    print(1)
    print(2)
    if 'a' in 'qux':
        print(3)
print(4)
# Out:
# 1
# 2
# 4

# %%
x={2,4,6}
s=0
for i in range(3):
    s = s + x.pop()
    
print(s)
# Out:
# 12

# %%
for num in range (-2,-5,-1):
    print(num,end=", ")
# Out:
# -2, -3, -4,

# %%
a = [1,3,5,7]
while a:
    print(a.pop())
    if len(a)<3:
        break
else:
    print("End")
# Out:
# 7
# 5

# %%
print("Hello World"[::-1])
# Out:
# dlroW olleH

# %%
my_variable = 5
print(my_variable)
# Out:
# 5

# %%
elements = [1,2,3,4,5,6]
result = list(filter(lambda n: n%2==0, elements))
result
# Out:
# [2, 4, 6]

# %%
colors = {"red": "#FF0000", "green": "#00FF00", "blue": "#0000FF"}
colors
# Out:
# {'red': '#FF0000', 'green': '#00FF00', 'blue': '#0000FF'}

# %%
words = ["hello", "wilhelm", "hey", "bill"]
short_words = [word for word in words if len(word) <= 5]
short_words
# Out:
# ['hello', 'hey', 'bill']

# %%
words = ["hello", "wilhelm", "hey", "bill"]
long_words = list(filter(lambda n: len(words[n]) > 3, words))
long_words
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-2fca8e941a65> in <module>
#       1 words = ["hello", "wilhelm", "hey", "bill"]
# ----> 2 long_words = list(filter(lambda n: len(words[n]) > 3, words))
#       3 long_words
#
# TypeError: 'list' object is not callable

# %%
words = ["hello", "wilhelm", "hey", "bill"]
shortword = words[-1]
shortword
# Out:
# 'bill'

# %%
myList = ["hello", "wilhelm", "hey", "bill"]
myList.length
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-7c240a4a2dca> in <module>
#       1 myList = ["hello", "wilhelm", "hey", "bill"]
# ----> 2 myList.length
#
# AttributeError: 'list' object has no attribute 'length'

# %%
my_list = ["hello", "wilhelm", "hey", "bill"]
my_list[len(mylist)::-1]
my_list
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-0163d9c7daa5> in <module>
#       1 my_list = ["hello", "wilhelm", "hey", "bill"]
# ----> 2 my_list[len(mylist)::-1]
#       3 my_list
#
# NameError: name 'mylist' is not defined
