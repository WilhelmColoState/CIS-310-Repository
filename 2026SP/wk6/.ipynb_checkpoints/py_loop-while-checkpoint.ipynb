# %% [markdown]
# # WIlhelm Lange
# ## week 6 - 03/03/2026
# ### Python while loops

# %%
** the general format of python while loops**

<code> while boolean-test:
            statement/s </code>
# Out:
#   File "<ipython-input-2-8145951b29d8>", line 1
#     ** the general format of python while loops**
#      ^
# SyntaxError: invalid syntax

# %%
lst = list(range(1,9))
lst
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
n = 0
while n < len(lst):
    print(lst[n])
    n = n+1
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8

# %%
while lst:
    print(lst.pop())
# Out:
# 8
# 7
# 6
# 5
# 4
# 3
# 2
# 1

# %%
lst
# Out:
# []

# %%
#break keyword
lst = list(range(10, 19))

lst
# Out:
# [10, 11, 12, 13, 14, 15, 16, 17, 18]

# %%
n = 0
while n < len(lst):
    if lst[n] == 15:
        n +=1
        continue
    print(lst[n])
    n+= 1
# Out:
# 10
# 11
# 12
# 13
# 14
# 16
# 17
# 18
