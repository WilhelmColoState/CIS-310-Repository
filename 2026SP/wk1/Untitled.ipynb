# %% [markdown]
# # Wilhelm Lange
# ## Week 1 - 01/22/2026
# ### Python - Practice Numbers

# %%
5 + 5
# Out:
# 10

# %%
5 * 5
# Out:
# 25

# %%
5%2
# Out:
# 1

# %%
6%4
# Out:
# 2

# %%
6 ** 7
# Out:
# 279936

# %%
# floor divide
3 //
