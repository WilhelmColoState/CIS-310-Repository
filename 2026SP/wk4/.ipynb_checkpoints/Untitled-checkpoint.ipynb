# %% [markdown]
# # Week 4 - 02/12/2026
# ## Python Tuples: (), tuple()
# - tuple is a collection that is ordered and unchangable
# - ordered - items have a defined order, index
# - unchangable - cannot change/update, add, or remove items after creation

# %%
#create a new tuple()
t = (10, 120, 'a', 'b', 'CIS310', True, False)

# %%
t(0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-d94944e4966c> in <module>
# ----> 1 t(0)
#
# TypeError: 'tuple' object is not callable

# %%
t
# Out:
# (10, 120, 'a', 'b', 'CIS310', True, False)

# %%
len(t)
# Out:
# 7
