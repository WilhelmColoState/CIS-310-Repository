# %% [markdown]
# # Wilhelm Lange
# ## 2/3/2026

# %%
word = "Hello\nCIS310!"
print(word)
# Out:
# Hello
# CIS310!

# %%
word = "Hello\tCIS310"
print(word)
# Out:
# Hello	CIS310

# %%
print("The quick brown %s jumps over the lazy %s" %('Fox','Dog'))
# Out:
# The quick brown Fox jumps over the lazy Dog

# %%
word1, word2 = 'fox', 'dog'
print("The quick brown %s jumps over the lazy %s" %(word1,word2))
# Out:
# The quick brown fox jumps over the lazy dog

# %%
print('My score in CIS310 is %.2f' %98.67)
# Out:
# My score in CIS310 is 98.67

# %%
print("Im using general purpose language {!r} to perform data analysis".format('python'))
# Out:
# Im using general purpose language 'python' to perform data analysis

# %%
words = ['lazy', 'dog', 'brown', 'fox']
print("The quick {2} {3} jumps over the {0} {1}".format(words))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-11-fdb6c447aef6> in <module>
#       1 words = ['lazy', 'dog', 'brown', 'fox']
# ----> 2 print("The quick {2} {3} jumps over the {0} {1}".format(words))
#
# IndexError: tuple index out of range

# %%
#using f-strings
n = "Wilhelm Lange"
t = "CIS-320"
print(f'{n} is a student in {t}')
# Out:
# Wilhelm Lange is a student in CIS-320

# %%
#numbers
radius = 2.535
area = (radius**2)* 1.1415
area
# Out:
# 7.3355358375

# %%
print(f'the area of the radius {radius} is {area:.2f}')
# Out:
# the area of the radius 2.535 is 7.33

# %%
# using python input funtcion
n = input('Enter a number ')
print(f'n = {n}, and the type is {type(n)}')
# Out:
# Enter a number 67
# n = 67, and the type is <class 'str'>

# %%
# using python input funtcion
n = int(input('Enter a number '))
print(f'n = {n}, and the type is {type(n)}')
# Out:
# Enter a number 67
# n = 67, and the type is <class 'int'>

# %%
type(n)
# Out:
# int

# %%
# using python input funtcion
radius = float(input('Enter radius: '))
area = (radius**2)* 1.1415
print(f'the area of the radius {radius} is {area:.2f}')
# Out:
# Enter radius: 67
# the area of the radius 67.0 is 5124.19

# %%
# cast to boolean
x = bool(0)
y = bool(3)
z = bool(-1)
print(f"{x}, {y}, {z}")
# Out:
# False, True, True
