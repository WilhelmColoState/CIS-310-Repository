# %% [markdown]
# # Wilhelm Lange
#
# ## Week 11 - 31/3/2026
# ### Python Numpy Intro

# %%
What is Numpy? 
- NumPy is a python library
- NUmPy is short for "Numberical Python"
- 50x faster than python lists
# Out:
#   File "<ipython-input-1-2b1e343c4a27>", line 1
#     What is Numpy?
#                  ^
# SyntaxError: invalid syntax

# %%
import numpy as np
import random

# %%
lst = random.choices(range(5,11), k=15)
lst
# Out:
# [6, 9, 6, 5, 8, 9, 9, 5, 9, 5, 7, 8, 5, 9, 8]

# %%
type(lst)
# Out:
# list

# %%
arr = np.array(lst)
arr
# Out:
# array([6, 9, 6, 5, 8, 9, 9, 5, 9, 5, 7, 8, 5, 9, 8])

# %%
type(arr)
# Out:
# numpy.ndarray

# %%
# Dimensions in numpy Arrays
# A deimension in arrays is one level of array depth (nested arrays)
# A nested array: are arrays that have arrays as their elements
arr_0 = np.array(45)
arr_0
# Out:
# array(45)

# %%
arr_0.ndim
# Out:
# 0

# %%
# 1-D array:An array whose elements are 0-D array
arr_1 = np.array(lst)
arr_1
# Out:
# array([6, 9, 6, 5, 8, 9, 9, 5, 9, 5, 7, 8, 5, 9, 8])

# %%
arr_1.ndim
# Out:
# 1

# %%
# 2-D array: an array whose elements are 1-D arrays

arr_2 = np.array([arr_1, arr_1 * 2])
arr_2
# Out:
# array([[ 6,  9,  6,  5,  8,  9,  9,  5,  9,  5,  7,  8,  5,  9,  8],
#        [12, 18, 12, 10, 16, 18, 18, 10, 18, 10, 14, 16, 10, 18, 16]])

# %%
arr_2.ndim
# Out:
# 2

# %%
arr_2.shape
# Out:
# (2, 15)

# %%
# 3-D array: An array that has 2-D arrays (matrices) as its elements
arr_3 = np.array([arr_2, arr_2 * 2])
arr_3
# Out:
# array([[[ 6,  9,  6,  5,  8,  9,  9,  5,  9,  5,  7,  8,  5,  9,  8],
#         [12, 18, 12, 10, 16, 18, 18, 10, 18, 10, 14, 16, 10, 18, 16]],
#
#        [[12, 18, 12, 10, 16, 18, 18, 10, 18, 10, 14, 16, 10, 18, 16],
#         [24, 36, 24, 20, 32, 36, 36, 20, 36, 20, 28, 32, 20, 36, 32]]])

# %%
arr_3.ndim
# Out:
# 3

# %%
len(arr_3)
# Out:
# 2

# %%
arr_3.shape
# Out:
# (2, 2, 15)

# %%
arr_4 = np.array([1,2,3,4,5], ndmin=4)
arr_4
# Out:
# array([[[[1, 2, 3, 4, 5]]]])

# %%
arr_4.shape
# Out:
# (1, 1, 1, 5)

# %%
arr_1
# Out:
# array([6, 9, 6, 5, 8, 9, 9, 5, 9, 5, 7, 8, 5, 9, 8])

# %%
arr_1[0]
# Out:
# 6

# %%
arr_1[14]
# Out:
# 8

# %%
arr[-1]
# Out:
# 8

# %%
arr_2.shape
# Out:
# (2, 15)

# %%
arr_2[0]
# Out:
# array([6, 9, 6, 5, 8, 9, 9, 5, 9, 5, 7, 8, 5, 9, 8])

# %%
arr_2[1]
# Out:
# array([12, 18, 12, 10, 16, 18, 18, 10, 18, 10, 14, 16, 10, 18, 16])

# %%
arr_2[1,-1]
# Out:
# 16

# %%
arr_2[0,5]
# Out:
# 9

# %%
arr_3
# Out:
# array([[[ 6,  9,  6,  5,  8,  9,  9,  5,  9,  5,  7,  8,  5,  9,  8],
#         [12, 18, 12, 10, 16, 18, 18, 10, 18, 10, 14, 16, 10, 18, 16]],
#
#        [[12, 18, 12, 10, 16, 18, 18, 10, 18, 10, 14, 16, 10, 18, 16],
#         [24, 36, 24, 20, 32, 36, 36, 20, 36, 20, 28, 32, 20, 36, 32]]])

# %%
arr_3.shape
# Out:
# (2, 2, 15)

# %%
arr_3[0]
# Out:
# array([[ 6,  9,  6,  5,  8,  9,  9,  5,  9,  5,  7,  8,  5,  9,  8],
#        [12, 18, 12, 10, 16, 18, 18, 10, 18, 10, 14, 16, 10, 18, 16]])

# %%
arr_3[1]
# Out:
# array([[12, 18, 12, 10, 16, 18, 18, 10, 18, 10, 14, 16, 10, 18, 16],
#        [24, 36, 24, 20, 32, 36, 36, 20, 36, 20, 28, 32, 20, 36, 32]])

# %%
arr_3[1, 1]
# Out:
# array([24, 36, 24, 20, 32, 36, 36, 20, 36, 20, 28, 32, 20, 36, 32])

# %%
arr_3[1,1]
# Out:
# array([24, 36, 24, 20, 32, 36, 36, 20, 36, 20, 28, 32, 20, 36, 32])

# %%
arr_3[0,1,-1]
# Out:
# 16

# %%
arr_3[0][1][-1]
# Out:
# 16

# %%
# slicing numpy arrays: [start:end:step]
arr_1
# Out:
# array([6, 9, 6, 5, 8, 9, 9, 5, 9, 5, 7, 8, 5, 9, 8])

# %%
arr_1[0:10]
# Out:
# array([6, 9, 6, 5, 8, 9, 9, 5, 9, 5])

# %%
arr_1[-10:]
# Out:
# array([9, 9, 5, 9, 5, 7, 8, 5, 9, 8])

# %%
arr_1.shape
# Out:
# (15,)

# %%
arr_2
# Out:
# array([[ 6,  9,  6,  5,  8,  9,  9,  5,  9,  5,  7,  8,  5,  9,  8],
#        [12, 18, 12, 10, 16, 18, 18, 10, 18, 10, 14, 16, 10, 18, 16]])

# %%
arr_2[:]
# Out:
# array([[ 6,  9,  6,  5,  8,  9,  9,  5,  9,  5,  7,  8,  5,  9,  8],
#        [12, 18, 12, 10, 16, 18, 18, 10, 18, 10, 14, 16, 10, 18, 16]])

# %%
arr_2.shape
# Out:
# (2, 15)

# %%
arr_2[1, -5:]
# Out:
# array([14, 16, 10, 18, 16])
