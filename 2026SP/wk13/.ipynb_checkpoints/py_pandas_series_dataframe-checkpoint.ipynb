# %% [markdown]
# # WIlhelm Lange
# ## Week 13 : 14/04/2026
# ### Python - Pandas Series and DataFrame

# %%
import numpy as np
from numpy.random import randn, random
import pandas as pd
from pandas import Series, DataFrame # * to import everything

# %%
# Panda Series: It is a one dimensional array holding data of any type
s = Series(randn(15) * 10)
s
# Out:
# 0     -5.473493
# 1     10.320492
# 2     -7.145682
# 3    -10.975444
# 4      6.632955
# 5      1.985866
# 6     -9.319772
# 7      6.058962
# 8     10.920953
# 9     13.575546
# 10    -0.481171
# 11     5.185783
# 12    -3.013598
# 13    15.405260
# 14    -5.580095
# dtype: float64

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
s.index
# Out:
# RangeIndex(start=0, stop=15, step=1)

# %%
s.values
# Out:
# array([ -5.47349328,  10.32049219,  -7.14568182, -10.97544423,
#          6.63295505,   1.98586575,  -9.31977171,   6.05896242,
#         10.9209528 ,  13.5755458 ,  -0.48117074,   5.18578344,
#         -3.01359805,  15.4052596 ,  -5.58009499])

# %%
s[:3]
# Out:
# 0    -5.473493
# 1    10.320492
# 2    -7.145682
# dtype: float64

# %%
s[14]
# Out:
# -5.580094987089811

# %%
# Create Labels
s = Series(np.arange(10,15), index=['w','x','y','z','t'])
s
# Out:
# w    10
# x    11
# y    12
# z    13
# t    14
# dtype: int32

# %%
s['w']
# Out:
# 10

# %%
so = Series([2520,1122,937,847,713], index = ['USA', 'Russia', 'Germany', 'UK', 'France'])
so
# Out:
# USA        2520
# Russia     1122
# Germany     937
# UK          847
# France      713
# dtype: int64

# %%
so['USA']
# Out:
# 2520

# %%
so[so > 800]
# Out:
# USA        2520
# Russia     1122
# Germany     937
# UK          847
# dtype: int64

# %%
so > 800
# Out:
# USA         True
# Russia      True
# Germany     True
# UK          True
# France     False
# dtype: bool

# %%
# Convert Series to dictionary
d = dict(so)
d
# Out:
# {'USA': 2520, 'Russia': 1122, 'Germany': 937, 'UK': 847, 'France': 713}

# %%
# Convert deictionary to series
s2 = Series(d)
s2
# Out:
# USA        2520
# Russia     1122
# Germany     937
# UK          847
# France      713
# dtype: int64

# %%
# merge
country = ['Russia', 'France', 'Spain', 'Germany', 'USA', 'UK', 'Italy']
country
# Out:
# ['Russia', 'France', 'Spain', 'Germany', 'USA', 'UK', 'Italy']

# %%
s2 = Series(d, index=country)
s2
# Out:
# Russia     1122.0
# France      713.0
# Spain         NaN
# Germany     937.0
# USA        2520.0
# UK          847.0
# Italy         NaN
# dtype: float64

# %%
pd.isnull(s2)
# Out:
# Russia     False
# France     False
# Spain       True
# Germany    False
# USA        False
# UK         False
# Italy       True
# dtype: bool

# %%
pd.notnull(s2)
# Out:
# Russia      True
# France      True
# Spain      False
# Germany     True
# USA         True
# UK          True
# Italy      False
# dtype: bool

# %%
s2
# Out:
# Russia     1122.0
# France      713.0
# Spain         NaN
# Germany     937.0
# USA        2520.0
# UK          847.0
# Italy         NaN
# dtype: float64

# %%
so + s2
# Out:
# France     1426.0
# Germany    1874.0
# Italy         NaN
# Russia     2244.0
# Spain         NaN
# UK         1694.0
# USA        5040.0
# dtype: float64

# %%
s2
# Out:
# Russia     1122.0
# France      713.0
# Spain         NaN
# Germany     937.0
# USA        2520.0
# UK          847.0
# Italy         NaN
# dtype: float64

# %%
s2.name = "Summer Olympic"
s2
# Out:
# Russia     1122.0
# France      713.0
# Spain         NaN
# Germany     937.0
# USA        2520.0
# UK          847.0
# Italy         NaN
# Name: Summer Olympic, dtype: float64

# %%
s2.index.name = 'Country'
s2
# Out:
# Country
# Russia     1122.0
# France      713.0
# Spain         NaN
# Germany     937.0
# USA        2520.0
# UK          847.0
# Italy         NaN
# Name: Summer Olympic, dtype: float64

# %%
# DataFrame: is a 2 dimensional array
d = {
    "calories": [420, 380, 390],
    "fruits": ['Orange', 'Banana', 'Grape']
}
d
# Out:
# {'calories': [420, 380, 390], 'fruits': ['Orange', 'Banana', 'Grape']}

# %%
df = DataFrame(d)
df
# Out:
#    calories  fruits
# 0       420  Orange
# 1       380  Banana
# 2       390   Grape

# %%
df.describe()
# Out:
#          calories
# count    3.000000
# mean   396.666667
# std     20.816660
# min    380.000000
# 25%    385.000000
# 50%    390.000000
# 75%    405.000000
# max    420.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   calories  3 non-null      int64
#  1   fruits    3 non-null      object
# dtypes: int64(1), object(1)
# memory usage: 176.0+ bytes

# %%
df['calories']
# Out:
# 0    420
# 1    380
# 2    390
# Name: calories, dtype: int64

# %%
df['fruits']
# Out:
# 0    Orange
# 1    Banana
# 2     Grape
# Name: fruits, dtype: object

# %%
df
# Out:
#    calories  fruits
# 0       420  Orange
# 1       380  Banana
# 2       390   Grape

# %%
# Locate Row
df.loc[0]
# Out:
# calories       420
# fruits      Orange
# Name: 0, dtype: object

# %%
df.loc[2]
# Out:
# calories      390
# fruits      Grape
# Name: 2, dtype: object

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df['fruits'])
# Out:
# pandas.core.series.Series

# %%
type(df.loc[1])
# Out:
# pandas.core.series.Series

# %%
df.loc[[0,2]]
# Out:
#    calories  fruits
# 0       420  Orange
# 2       390   Grape

# %%
df.loc[[2,1]]
# Out:
#    calories  fruits
# 2       390   Grape
# 1       380  Banana

# %%
df2 = DataFrame({
    'state' : ['Ohio', 'Ohio', 'Ohio', 'Nevada', 'Nevada', 'Nevada'],
    'year': [2000, 2001, 2002, 2001 , 2002,2003 ],
    'pop' : [1.5, 1.7, 3.6, 2.4, 2.9, 3.2]
})

df2
# Out:
#     state  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9
# 5  Nevada  2003  3.2

# %%
df2.head()
# Out:
#     state  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9

# %%
df2.tail()
# Out:
#     state  year  pop
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9
# 5  Nevada  2003  3.2

# %%
df3 = DataFrame(df2, columns=['year', 'state', 'pop'])
df3
# Out:
#    year   state  pop
# 0  2000    Ohio  1.5
# 1  2001    Ohio  1.7
# 2  2002    Ohio  3.6
# 3  2001  Nevada  2.4
# 4  2002  Nevada  2.9
# 5  2003  Nevada  3.2

# %%
df4 = DataFrame({
    'state' : ['Ohio', 'Ohio', 'Ohio', 'Nevada', 'Nevada', 'Nevada'],
    'year': [2000, 2001, 2002, 2001 , 2002,2003 ],
    'pop' : [1.5, 1.7, 3.6, 2.4, 2.9, 3.2]
}, columns=['year', 'state', 'pop'],
               index=['one', 'two', 'three', 'four', 'five', 'six'])
df4
# Out:
#        year   state  pop
# one    2000    Ohio  1.5
# two    2001    Ohio  1.7
# three  2002    Ohio  3.6
# four   2001  Nevada  2.4
# five   2002  Nevada  2.9
# six    2003  Nevada  3.2

# %%
df4.index
# Out:
# Index(['one', 'two', 'three', 'four', 'five', 'six'], dtype='object')

# %%
df4.columns
# Out:
# Index(['year', 'state', 'pop'], dtype='object')

# %%
df4['state']
# Out:
# one        Ohio
# two        Ohio
# three      Ohio
# four     Nevada
# five     Nevada
# six      Nevada
# Name: state, dtype: object

# %%
df4['state']
# Out:
# one        Ohio
# two        Ohio
# three      Ohio
# four     Nevada
# five     Nevada
# six      Nevada
# Name: state, dtype: object

# %%
df4[['state', 'pop']]
# Out:
#         state  pop
# one      Ohio  1.5
# two      Ohio  1.7
# three    Ohio  3.6
# four   Nevada  2.4
# five   Nevada  2.9
# six    Nevada  3.2

# %%
df4['year']
# Out:
# one      2000
# two      2001
# three    2002
# four     2001
# five     2002
# six      2003
# Name: year, dtype: int64

# %%
df4.loc['three']
# Out:
# year     2002
# state    Ohio
# pop       3.6
# Name: three, dtype: object

# %%
df4.loc[['two', 'four', 'three']]
# Out:
#        year   state  pop
# two    2001    Ohio  1.7
# four   2001  Nevada  2.4
# three  2002    Ohio  3.6

# %%
df4
# Out:
#        year   state  pop
# one    2000    Ohio  1.5
# two    2001    Ohio  1.7
# three  2002    Ohio  3.6
# four   2001  Nevada  2.4
# five   2002  Nevada  2.9
# six    2003  Nevada  3.2

# %%
df4.iloc[0]
# Out:
# year     2000
# state    Ohio
# pop       1.5
# Name: one, dtype: object

# %%
df4.iloc[[1,3,0]]
# Out:
#       year   state  pop
# two   2001    Ohio  1.7
# four  2001  Nevada  2.4
# one   2000    Ohio  1.5

# %%
df4.iloc[:3]
# Out:
#        year state  pop
# one    2000  Ohio  1.5
# two    2001  Ohio  1.7
# three  2002  Ohio  3.6

# %%
# add a new column
df4['debt'] = 10
df4
# Out:
#        year   state  pop  debt
# one    2000    Ohio  1.5    10
# two    2001    Ohio  1.7    10
# three  2002    Ohio  3.6    10
# four   2001  Nevada  2.4    10
# five   2002  Nevada  2.9    10
# six    2003  Nevada  3.2    10

# %%
len(df4['debt'])
# Out:
# 6

# %%
df4['debt'] = random(6) * 10
df4
# Out:
#        year   state  pop      debt
# one    2000    Ohio  1.5  4.202965
# two    2001    Ohio  1.7  1.777325
# three  2002    Ohio  3.6  2.139418
# four   2001  Nevada  2.4  6.705477
# five   2002  Nevada  2.9  6.393136
# six    2003  Nevada  3.2  1.413750

# %%
df4['debt'] = randn(len(df4['debt'])) * 10
df4
# Out:
#        year   state  pop       debt
# one    2000    Ohio  1.5   2.486098
# two    2001    Ohio  1.7 -14.958002
# three  2002    Ohio  3.6   9.106034
# four   2001  Nevada  2.4  23.121009
# five   2002  Nevada  2.9  -3.376719
# six    2003  Nevada  3.2   0.211748

# %%
df4['eastren'] = df4['state'] == 'Ohio'
df4
# Out:
#        year   state  pop       debt  eastren
# one    2000    Ohio  1.5   2.486098     True
# two    2001    Ohio  1.7 -14.958002     True
# three  2002    Ohio  3.6   9.106034     True
# four   2001  Nevada  2.4  23.121009    False
# five   2002  Nevada  2.9  -3.376719    False
# six    2003  Nevada  3.2   0.211748    False

# %%
df4[df4['pop'] > 2]
# Out:
#        year   state  pop       debt  eastren
# three  2002    Ohio  3.6   9.106034     True
# four   2001  Nevada  2.4  23.121009    False
# five   2002  Nevada  2.9  -3.376719    False
# six    2003  Nevada  3.2   0.211748    False

# %%
df4[df4['state'] == 'Nevada']
# Out:
#       year   state  pop       debt  eastren
# four  2001  Nevada  2.4  23.121009    False
# five  2002  Nevada  2.9  -3.376719    False
# six   2003  Nevada  3.2   0.211748    False

# %%
df4.T
# Out:
#             one     two    three    four     five       six
# year       2000    2001     2002    2001     2002      2003
# state      Ohio    Ohio     Ohio  Nevada   Nevada    Nevada
# pop         1.5     1.7      3.6     2.4      2.9       3.2
# debt     2.4861 -14.958  9.10603  23.121 -3.37672  0.211748
# eastren    True    True     True   False    False     False

# %%
df4['pop'][:2]
# Out:
# one    1.5
# two    1.7
# Name: pop, dtype: float64

# %%
df4[['pop'][-2:]]
# Out:
#        pop
# one    1.5
# two    1.7
# three  3.6
# four   2.4
# five   2.9
# six    3.2

# %%
df4['pop'][-2:]
# Out:
# five    2.9
# six     3.2
# Name: pop, dtype: float64
