# %% [markdown]
# # Wilhelm Lange
# ## Week12: 04/16/2026 - 04/21/2026
# ### Python - Pandas DataFrame Processing

# %%
import numpy as np
import pandas as pd
from numpy.random import *
from pandas import *

# %%
#Drop Entries
df = DataFrame(np.arange(1,17).reshape((4,4)),
              columns=['one', 'two','three', 'four'],
              index=['Ohio', 'Colorado', 'Utah', 'New York'])
df
# Out:
#           one  two  three  four
# Ohio        1    2      3     4
# Colorado    5    6      7     8
# Utah        9   10     11    12
# New York   13   14     15    16

# %%
df.index
# Out:
# Index(['Ohio', 'Colorado', 'Utah', 'New York'], dtype='object')

# %%
df.index.name

# %%
df.drop(['Colorado'])
# Out:
#           one  two  three  four
# Ohio        1    2      3     4
# Utah        9   10     11    12
# New York   13   14     15    16

# %%
df.drop(['Utah', 'Ohio'])
# Out:
#           one  two  three  four
# Colorado    5    6      7     8
# New York   13   14     15    16

# %%
df
# Out:
#           one  two  three  four
# Ohio        1    2      3     4
# Colorado    5    6      7     8
# Utah        9   10     11    12
# New York   13   14     15    16

# %%
df.drop(['three'], axis='columns')
# Out:
#           one  two  four
# Ohio        1    2     4
# Colorado    5    6     8
# Utah        9   10    12
# New York   13   14    16

# %%
df.drop(['three'], axis=1)
# Out:
#           one  two  four
# Ohio        1    2     4
# Colorado    5    6     8
# Utah        9   10    12
# New York   13   14    16

# %%
df.drop(['three', 'one'], axis=1)
# Out:
#           two  four
# Ohio        2     4
# Colorado    6     8
# Utah       10    12
# New York   14    16

# %%
df1 = df.copy()
df1
# Out:
#           one  two  three  four
# Ohio        1    2      3     4
# Colorado    5    6      7     8
# Utah        9   10     11    12
# New York   13   14     15    16

# %%
df.drop(['three', 'one'], axis=1, inplace=True)

# %%
df
# Out:
#           two  four
# Ohio        2     4
# Colorado    6     8
# Utah       10    12
# New York   14    16

# %%
df1[df1['three'] >= 7]
# Out:
#           one  two  three  four
# Colorado    5    6      7     8
# Utah        9   10     11    12
# New York   13   14     15    16

# %%
# Data alignment
df1 = DataFrame(np.arange(9).reshape(3,3), columns=list('bcd'),
               index=['Ohio', 'Texas', 'Colorado'])

df2 = DataFrame(np.arange(12).reshape(4,3), columns=list('bde'),
               index=[ 'Utah','Ohio', 'Texas', 'Oregon'])

# %%
df1
# Out:
#           b  c  d
# Ohio      0  1  2
# Texas     3  4  5
# Colorado  6  7  8

# %%
df1 + df2
# Out:
#             b   c     d   e
# Colorado  NaN NaN   NaN NaN
# Ohio      3.0 NaN   6.0 NaN
# Oregon    NaN NaN   NaN NaN
# Texas     9.0 NaN  12.0 NaN
# Utah      NaN NaN   NaN NaN

# %%
df1.add(df2)
# Out:
#             b   c     d   e
# Colorado  NaN NaN   NaN NaN
# Ohio      3.0 NaN   6.0 NaN
# Oregon    NaN NaN   NaN NaN
# Texas     9.0 NaN  12.0 NaN
# Utah      NaN NaN   NaN NaN

# %%
df1
# Out:
#           b  c  d
# Ohio      0  1  2
# Texas     3  4  5
# Colorado  6  7  8

# %%
df2
# Out:
#         b   d   e
# Utah    0   1   2
# Ohio    3   4   5
# Texas   6   7   8
# Oregon  9  10  11

# %%
df1.add(df2, fill_value=0) # number + 0 instead of (number + nan = nan)
# Out:
#             b    c     d     e
# Colorado  6.0  7.0   8.0   NaN
# Ohio      3.0  1.0   6.0   5.0
# Oregon    9.0  NaN  10.0  11.0
# Texas     9.0  4.0  12.0   8.0
# Utah      0.0  NaN   1.0   2.0

# %%
df1['e'] = df1['b'] + df1['d']
df1
# Out:
#           b  c  d   e
# Ohio      0  1  2   2
# Texas     3  4  5   8
# Colorado  6  7  8  14

# %%
#sort and rank
df = DataFrame(np.random.choice(np.arange(1,21), size=8).reshape(2,4),
              columns=list('dabd'),
              index=['three', 'one'])
df
# Out:
#         d   a   b   d
# three  11  12   5  13
# one    18  15  19   8

# %%
df.sort_index()
# Out:
#         d   a   b   d
# one    18  15  19   8
# three  11  12   5  13

# %%
df.sort_index(axis=1)
# Out:
#         a   b   d   d
# three  12   5  11  13
# one    15  19  18   8

# %%
df
# Out:
#         d   a   b   d
# three  11  12   5  13
# one    18  15  19   8

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#         d   d   b   a
# three  11  13   5  12
# one    18   8  19  15

# %%
# Sort by values
df.sort_values(by='b')
# Out:
#         d   a   b   d
# three  11  12   5  13
# one    18  15  19   8

# %%
df.sort_values(by='d')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-3410ec4f31e9> in <module>
# ----> 1 df.sort_values(by='d')
#
# c:\Miniconda\envs\py37_default\lib\site-packages\pandas\core\frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index)
#    4925
#    4926             by = by[0]
# -> 4927             k = self._get_label_or_level_values(by, axis=axis)
#    4928
#    4929             if isinstance(ascending, (tuple, list)):
#
# c:\Miniconda\envs\py37_default\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis)
#    1708             raise ValueError(
#    1709                 (
# -> 1710                     f"The {label_axis_name} label '{key}' "
#    1711                     f"is not unique.{multi_message}"
#    1712                 )
#
# ValueError: The column label 'd' is not unique.

# %%
df = DataFrame(np.random.choice(np.arange(-10,20), size=16).reshape(4,4),
              columns=list('dabc'),
              index=['three', 'one', 'four', 'seven'])
df

# %%
df.sort_values(by='c')

# %%
df.sort_values(by=['a', 'd'])

# %%
df.sort_values(by='seven', axis = 1)

# %%
df.sort_values(by=['one','seven'], axis = 1)

# %%
df.sort_values(by=['one','seven'], axis = 1, inplace=True)

# %%
df

# %%
# Ranking
df.rank()

# %%
df.rank().astype(int)

# %%
df.values

# %%
# Statistics
df

# %%
df['e'] = np.where(df['a'] > 2, df['c'], np.nan)

# %%
df

# %%
df.sum()

# %%
df.sum(axis=1)

# %%
df.mean()

# %%
df.mean(axis='columns')

# %%
df.values

# %%
df.mean(axis=1, skipna=False)

# %%
df.min()

# %%
df.min(axis=1)

# %%
df.max(axis=1)

# %%
# idxmax() returns the index of the first occurrence of the maximum over the requested axis
df = DataFrame([np.random.choice(np.arange(-5,5), size=5), np.random.choice(np.arange(-5,5), size=5),np.random.choice(np.arange(-5,5), size=5),np.random.choice(np.arange(-5,5), size=5)]
              ,index=list('abcd'),
              columns=['one','two','three','four','five'])
df
# Out:
#    one  two  three  four  five
# a   -3    1      0    -5     0
# b    2   -4     -5     3     0
# c    1    1      2    -1     2
# d    3   -3     -3    -3     2

# %%
df
# Out:
#    one  two  three  four  five
# a   -3    1      0    -5     0
# b    2   -4     -5     3     0
# c    1    1      2    -1     2
# d    3   -3     -3    -3     2

# %%
df.idxmax()
# Out:
# one      d
# two      a
# three    c
# four     b
# five     c
# dtype: object

# %%
df.idxmin()
# Out:
# one      a
# two      b
# three    b
# four     a
# five     a
# dtype: object

# %%
df.idxmin(axis=1)
# Out:
# a     four
# b    three
# c     four
# d      two
# dtype: object

# %%
df
# Out:
#    one  two  three  four  five
# a   -3    1      0    -5     0
# b    2   -4     -5     3     0
# c    1    1      2    -1     2
# d    3   -3     -3    -3     2

# %%
# Create a Dataframe representing stock prices
data = {
    'Date': pd.date_range(start='2026-01-01', end='2026-01-10'),
    'META': np.random.choice(np.arange(100,300), size=10),
    'TSLA': np.random.choice(np.arange(100,300), size=10),
    'GOOGL': np.random.choice(np.arange(100,300), size=10),
}
data
# Out:
# {'Date': DatetimeIndex(['2026-01-01', '2026-01-02', '2026-01-03', '2026-01-04',
#                 '2026-01-05', '2026-01-06', '2026-01-07', '2026-01-08',
#                 '2026-01-09', '2026-01-10'],
#                dtype='datetime64[ns]', freq='D'),
#  'META': array([132, 282, 290, 107, 292, 139, 115, 286, 117, 216]),
#  'TSLA': array([193, 274, 189, 220, 136, 182, 273, 247, 164, 245]),
#  'GOOGL': array([215, 298, 225, 235, 292, 265, 179, 268, 269, 147])}

# %%
df = DataFrame(data, index=data['Date'], columns=['Meta', 'TSLA', 'GOOGL'])
df
# Out:
#            Meta  TSLA  GOOGL
# 2026-01-01  NaN   219    163
# 2026-01-02  NaN   219    102
# 2026-01-03  NaN   216    239
# 2026-01-04  NaN   272    185
# 2026-01-05  NaN   254    233
# 2026-01-06  NaN   287    105
# 2026-01-07  NaN   282    271
# 2026-01-08  NaN   194    208
# 2026-01-09  NaN   297    139
# 2026-01-10  NaN   108    295

# %%
df.index.name = 'Date'

# %%
# Find the date with th highest closing price for each stock 
df.idxmax()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-c747b887d6e7> in <module>
#       1 # Find the date with th highest closing price for each stock
# ----> 2 df.idxmax()
#
# c:\Miniconda\envs\py37_default\lib\site-packages\pandas\core\frame.py in idxmax(self, axis, skipna)
#    8083         """
#    8084         axis = self._get_axis_number(axis)
# -> 8085         indices = nanops.nanargmax(self.values, axis=axis, skipna=skipna)
#    8086         index = self._get_axis(axis)
#    8087         result = [index[i] if i >= 0 else np.nan for i in indices]
#
# c:\Miniconda\envs\py37_default\lib\site-packages\pandas\core\nanops.py in _f(*args, **kwargs)
#      63                 f_name = f.__name__.replace("nan", "")
#      64                 raise TypeError(
# ---> 65                     f"reduction operation '{f_name}' not allowed for this dtype"
# ...

# %%
df.idxmin()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-e5948d797101> in <module>
# ----> 1 df.idxmin()
#
# c:\Miniconda\envs\py37_default\lib\site-packages\pandas\core\frame.py in idxmin(self, axis, skipna)
#    8045         """
#    8046         axis = self._get_axis_number(axis)
# -> 8047         indices = nanops.nanargmin(self.values, axis=axis, skipna=skipna)
#    8048         index = self._get_axis(axis)
#    8049         result = [index[i] if i >= 0 else np.nan for i in indices]
#
# c:\Miniconda\envs\py37_default\lib\site-packages\pandas\core\nanops.py in _f(*args, **kwargs)
#      63                 f_name = f.__name__.replace("nan", "")
#      64                 raise TypeError(
# ---> 65                     f"reduction operation '{f_name}' not allowed for this dtype"
#      66                 )
#      67             try:
#
# ...

# %%
df_t = df.T
df_t
# Out:
# Date  2026-01-01 2026-01-02 2026-01-03 2026-01-04 2026-01-05 2026-01-06  \
# Meta         NaN        NaN        NaN        NaN        NaN        NaN
# TSLA         219        219        216        272        254        287
# GOOGL        163        102        239        185        233        105
#
# Date  2026-01-07 2026-01-08 2026-01-09 2026-01-10
# Meta         NaN        NaN        NaN        NaN
# TSLA         282        194        297        108
# GOOGL        271        208        139        295

# %%
# Find the stock with the minumum and maimum calues for a specific date: "2026-01-02"
df_t['2026-01-02'].idxmax()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-359304fd2467> in <module>
#       1 # Find the stock with the minumum and maimum calues for a specific date: "2026-01-02"
# ----> 2 df_t['2026-01-02'].idxmax()
#
# c:\Miniconda\envs\py37_default\lib\site-packages\pandas\core\series.py in idxmax(self, axis, skipna, *args, **kwargs)
#    2108         """
#    2109         skipna = nv.validate_argmax_with_skipna(skipna, args, kwargs)
# -> 2110         i = nanops.nanargmax(com.values_from_object(self), skipna=skipna)
#    2111         if i == -1:
#    2112             return np.nan
#
# c:\Miniconda\envs\py37_default\lib\site-packages\pandas\core\nanops.py in _f(*args, **kwargs)
#      63                 f_name = f.__name__.replace("nan", "")
#      64                 raise TypeError(
# ...

# %%
df_t['2026-01-02'].idxmax()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-a62f99520762> in <module>
# ----> 1 df_t['2026-01-02'].idxmax()
#
# c:\Miniconda\envs\py37_default\lib\site-packages\pandas\core\series.py in idxmax(self, axis, skipna, *args, **kwargs)
#    2108         """
#    2109         skipna = nv.validate_argmax_with_skipna(skipna, args, kwargs)
# -> 2110         i = nanops.nanargmax(com.values_from_object(self), skipna=skipna)
#    2111         if i == -1:
#    2112             return np.nan
#
# c:\Miniconda\envs\py37_default\lib\site-packages\pandas\core\nanops.py in _f(*args, **kwargs)
#      63                 f_name = f.__name__.replace("nan", "")
#      64                 raise TypeError(
# ---> 65                     f"reduction operation '{f_name}' not allowed for this dtype"
#      66                 )
#      67             try:
#
# ...

# %%
df.loc['2026-01-02'].idxmax()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-d9821baa1843> in <module>
# ----> 1 df.loc['2026-01-02'].idxmax()
#
# c:\Miniconda\envs\py37_default\lib\site-packages\pandas\core\series.py in idxmax(self, axis, skipna, *args, **kwargs)
#    2108         """
#    2109         skipna = nv.validate_argmax_with_skipna(skipna, args, kwargs)
# -> 2110         i = nanops.nanargmax(com.values_from_object(self), skipna=skipna)
#    2111         if i == -1:
#    2112             return np.nan
#
# c:\Miniconda\envs\py37_default\lib\site-packages\pandas\core\nanops.py in _f(*args, **kwargs)
#      63                 f_name = f.__name__.replace("nan", "")
#      64                 raise TypeError(
# ---> 65                     f"reduction operation '{f_name}' not allowed for this dtype"
#      66                 )
#      67             try:
#
# ...

# %%
# Missing data
sample = np.append(np.arange(1,6),[np.nan,np.nan])

df = DataFrame([np.random.choice(sample, size=5), np.random.choice(sample),size=5), np.random.choice(sample),size=5), np.random.choice(sample),size=5), np.random.choice(sample),size=5),
               index=list('abcd'),
               columns=['one','two','three','four','five']])
df
# Out:
#   File "<ipython-input-49-97fbad70915b>", line 4
#     df = DataFrame([np.random.choice(sample, size=5), np.random.choice(sample),size=5), np.random.choice(sample),size=5), np.random.choice(sample),size=5), np.random.choice(sample),size=5),
#                                                                                    ^
# SyntaxError: invalid syntax

# %%
df.drop
# Out:
# <bound method DataFrame.drop of            Meta  TSLA  GOOGL
# Date
# 2026-01-01  NaN   219    163
# 2026-01-02  NaN   219    102
# 2026-01-03  NaN   216    239
# 2026-01-04  NaN   272    185
# 2026-01-05  NaN   254    233
# 2026-01-06  NaN   287    105
# 2026-01-07  NaN   282    271
# 2026-01-08  NaN   194    208
# 2026-01-09  NaN   297    139
# 2026-01-10  NaN   108    295>

# %%
#using thresh to keep only rows having 2 or more valid data
df.dropna(thresh=4)
# Out:
# Empty DataFrame
# Columns: [Meta, TSLA, GOOGL]
# Index: []

# %%
# address nan values
df.fillna(0)
# Out:
#             Meta  TSLA  GOOGL
# Date
# 2026-01-01     0   219    163
# 2026-01-02     0   219    102
# 2026-01-03     0   216    239
# 2026-01-04     0   272    185
# 2026-01-05     0   254    233
# 2026-01-06     0   287    105
# 2026-01-07     0   282    271
# 2026-01-08     0   194    208
# 2026-01-09     0   297    139
# 2026-01-10     0   108    295

# %%
df.ffil()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-53-ae1c6f82b48e> in <module>
# ----> 1 df.ffil()
#
# c:\Miniconda\envs\py37_default\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'ffil'

# %%
df.fillna(df.mean())
# Out:
#             Meta  TSLA  GOOGL
# Date
# 2026-01-01   NaN   219    163
# 2026-01-02   NaN   219    102
# 2026-01-03   NaN   216    239
# 2026-01-04   NaN   272    185
# 2026-01-05   NaN   254    233
# 2026-01-06   NaN   287    105
# 2026-01-07   NaN   282    271
# 2026-01-08   NaN   194    208
# 2026-01-09   NaN   297    139
# 2026-01-10   NaN   108    295

# %%
df.fillna(df.max(), axis=1)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-55-0bd3047765bc> in <module>
# ----> 1 df.fillna(df.max(), axis=1)
#
# c:\Miniconda\envs\py37_default\lib\site-packages\pandas\core\frame.py in fillna(self, value, method, axis, inplace, limit, downcast)
#    4151             inplace=inplace,
#    4152             limit=limit,
# -> 4153             downcast=downcast,
#    4154         )
#    4155
#
# c:\Miniconda\envs\py37_default\lib\site-packages\pandas\core\generic.py in fillna(self, value, method, axis, inplace, limit, downcast)
#    6220                 if axis == 1:
#    6221                     raise NotImplementedError(
# -> 6222                         "Currently only can fill "
#    6223                         "with dict/Series column "
#    6224                         "by column"
#
# ...

# %%
df.fillna(df.max())
# Out:
#             Meta  TSLA  GOOGL
# Date
# 2026-01-01   NaN   219    163
# 2026-01-02   NaN   219    102
# 2026-01-03   NaN   216    239
# 2026-01-04   NaN   272    185
# 2026-01-05   NaN   254    233
# 2026-01-06   NaN   287    105
# 2026-01-07   NaN   282    271
# 2026-01-08   NaN   194    208
# 2026-01-09   NaN   297    139
# 2026-01-10   NaN   108    295

# %%
df.fillna(df.max(), inplace=True)

# %%
df
# Out:
#             Meta  TSLA  GOOGL
# Date
# 2026-01-01   NaN   219    163
# 2026-01-02   NaN   219    102
# 2026-01-03   NaN   216    239
# 2026-01-04   NaN   272    185
# 2026-01-05   NaN   254    233
# 2026-01-06   NaN   287    105
# 2026-01-07   NaN   282    271
# 2026-01-08   NaN   194    208
# 2026-01-09   NaN   297    139
# 2026-01-10   NaN   108    295

# %%
data = {
    'CustomerID': [1001, 1002,1003,1004],
    'Name': ['Alice', 'Bob', 'Charlie', 'David'],
    'Age': [25,30,None,22],
    'Income': [50000, None, 70000, 60000]
}

df = DataFrame(data)
df
# Out:
#    CustomerID     Name   Age   Income
# 0        1001    Alice  25.0  50000.0
# 1        1002      Bob  30.0      NaN
# 2        1003  Charlie   NaN  70000.0
# 3        1004    David  22.0  60000.0

# %%
df = df.set_index('CustomerID')
df
# Out:
#                Name   Age   Income
# CustomerID
# 1001          Alice  25.0  50000.0
# 1002            Bob  30.0      NaN
# 1003        Charlie   NaN  70000.0
# 1004          David  22.0  60000.0

# %%
df['Age'].fillna(df['Age'].mean(),inplace=True)
df['Age'] = df['Age'].astype(int)
df
# Out:
#                Name  Age   Income
# CustomerID
# 1001          Alice   25  50000.0
# 1002            Bob   30      NaN
# 1003        Charlie   25  70000.0
# 1004          David   22  60000.0
